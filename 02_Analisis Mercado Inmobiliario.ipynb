# %% [markdown]
# ## Importe de Librerías

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sqlalchemy as sa
import matplotlib.pyplot as plt

# %matplotlib inline
# %config IPCompleter.greedy = True

# %% [markdown]
# ## Datos

# %%
listings = pd.read_csv('../Datos/listings.csv')
listings
# Out:
#                         id                                               name  \
# 0                     6369  Rental unit in Madrid · ★4.88 · 1 bedroom · 1 ...
# 1                    30320  Rental unit in Madrid · ★4.63 · 1 bedroom · 2 ...
# 2                    21853  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...
# 3                    24805  Rental unit in Madrid · ★4.91 · 6 bedrooms · 1...
# 4                    30959  Loft in Madrid · ★4.38 · 1 bedroom · 1 bed · 1...
# ...                    ...                                                ...
# 25538  1046219783290634155  Rental unit in Madrid · ★New · 2 bedrooms · 3 ...
# 25539  1045519419976898566  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 25540  1046222300986271054  Rental unit in Madrid · ★New · 1 bedroom · 1 b...
# 25541  1046239141714406672  Rental unit in Madrid · ★New · 2 bedrooms · 4 ...
# 25542  1046255434342767173  Rental unit in Madrid · ★New · 1 bedroom · 3 b...
#
# ...

# %%
listings.head()
# Out:
#       id                                               name    host_id  \
# 0   6369  Rental unit in Madrid · ★4.88 · 1 bedroom · 1 ...      13660
# 1  30320  Rental unit in Madrid · ★4.63 · 1 bedroom · 2 ...     130907
# 2  21853  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...      83531
# 3  24805  Rental unit in Madrid · ★4.91 · 6 bedrooms · 1...  346366726
# 4  30959  Loft in Madrid · ★4.38 · 1 bedroom · 1 bed · 1...     132883
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0     Simon           Chamartín  Hispanoamérica  40.45724   -3.67688
# 1      Dana              Centro             Sol  40.41476   -3.70418
# 2     Abdel              Latina        Cármenes  40.40381   -3.74130
# 3    Alvaro              Centro     Universidad  40.42183   -3.70529
# 4    Angela              Centro     Embajadores  40.41259   -3.70105
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25543 entries, 0 to 25542
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              25543 non-null  int64
#  1   name                            25543 non-null  object
#  2   host_id                         25543 non-null  int64
#  3   host_name                       25532 non-null  object
#  4   neighbourhood_group             25543 non-null  object
#  5   neighbourhood                   25543 non-null  object
#  6   latitude                        25543 non-null  float64
#  7   longitude                       25543 non-null  float64
#  8   room_type                       25543 non-null  object
#  9   price                           21734 non-null  float64
#  10  minimum_nights                  25543 non-null  int64
#  11  number_of_reviews               25543 non-null  int64
# ...

# %%
listings_D = pd.read_csv('../Datos/listings.csv.gz', compression = 'gzip')
listings_D
# Out:
#                         id                                       listing_url  \
# 0                     6369                 https://www.airbnb.com/rooms/6369
# 1                    21853                https://www.airbnb.com/rooms/21853
# 2                    24805                https://www.airbnb.com/rooms/24805
# 3                    26825                https://www.airbnb.com/rooms/26825
# 4                    30320                https://www.airbnb.com/rooms/30320
# ...                    ...                                               ...
# 25538  1045513235996315049  https://www.airbnb.com/rooms/1045513235996315049
# 25539  1045517912453641702  https://www.airbnb.com/rooms/1045517912453641702
# 25540  1045518757044319450  https://www.airbnb.com/rooms/1045518757044319450
# 25541  1045519103468143325  https://www.airbnb.com/rooms/1045519103468143325
# 25542  1045519419976898566  https://www.airbnb.com/rooms/1045519419976898566
#
# ...

# %%
listings_D.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   6369   https://www.airbnb.com/rooms/6369  20231215032748   2023-12-15
# 1  21853  https://www.airbnb.com/rooms/21853  20231215032748   2023-12-15
# 2  24805  https://www.airbnb.com/rooms/24805  20231215032748   2023-12-15
# 3  26825  https://www.airbnb.com/rooms/26825  20231215032748   2023-12-15
# 4  30320  https://www.airbnb.com/rooms/30320  20231215032748   2023-12-15
#
#             source                                               name  \
# 0      city scrape  Rental unit in Madrid · ★4.88 · 1 bedroom · 1 ...
# 1      city scrape  Rental unit in Madrid · ★4.58 · 1 bedroom · 1 ...
# 2      city scrape  Rental unit in Madrid · ★4.91 · 6 bedrooms · 1...
# 3      city scrape  Home in Madrid · ★4.72 · 1 bedroom · 1 bed · 1...
# 4  previous scrape  Rental unit in Madrid · ★4.63 · 1 bedroom · 2 ...
#
#    description                              neighborhood_overview  \
# ...

# %%
listings_D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25543 entries, 0 to 25542
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            25543 non-null  int64
#  1   listing_url                                   25543 non-null  object
#  2   scrape_id                                     25543 non-null  int64
#  3   last_scraped                                  25543 non-null  object
#  4   source                                        25543 non-null  object
#  5   name                                          25543 non-null  object
#  6   description                                   0 non-null      float64
#  7   neighborhood_overview                         13137 non-null  object
#  8   picture_url                                   25542 non-null  object
# ...

# %% [markdown]
# Conclusiones:
#
# * Son los mismos registros pero el fichero de detalle tiene más columnas.
# * Es posible unir las tablas mediante el campo id

# %%
con = sa.create_engine('sqlite:///../Datos/AIRBNB.db')

listings.to_sql('listings', con = con, if_exists = 'replace')
listings_D.to_sql('listings_D', con = con, if_exists = 'replace', index = False)
# Out:
# 25543
